# %%
file = open('GIT_COMMANDS.txt')

# %%
print(dir(file))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
file.read()
# Out:
# ''

# %%
file.tell()
# Out:
# 1434

# %%
file.seek(0)
# Out:
# 0

# %%
file.read()
# Out:
# 'k,jjfirst of all create a repository on your git hub account\n\nthan open powershell and go to your code folder\n\n#\n#git init --> it initlize your current folder  as a git repository\n# \nvim README.md --> overview or discreption of your repository\n# \n\n#git config --global user.name gitusername\n# \n\n#git config --global user.email git email address\nconfig command will configure your credentials over git repository and if you\n used --global it will apply to all repository current or future\n\n#\n#git add . --> it will add all files from current repository\n#\n#git status --> staging area, where we can which files are added and which are\nstill to be added at git staging area\n#\n#git commit -m "any message regarding changes" --> This will create a version\n for your git repository, every time you commit something you are creating a \nnew version of your code\n\n\n#git remote add origin https://gihub.com/username/project_name.git --> it will\nlink your online repository to of
# ...

# %%
data = file.read()

# %%
print(data)
# Out:
# k,jjfirst of all create a repository on your git hub account
#
# than open powershell and go to your code folder
#
# #
# #git init --> it initlize your current folder  as a git repository
# #
# vim README.md --> overview or discreption of your repository
# #
#
# #git config --global user.name gitusername
# #
#
# #git config --global user.email git email address
# config command will configure your credentials over git repository and if you
#  used --global it will apply to all repository current or future
#
# #
# #git add . --> it will add all files from current repository
# #
# #git status --> staging area, where we can which files are added and which are
# still to be added at git staging area
# #
# #git commit -m "any message regarding changes" --> This will create a version
#  for your git repository, every time you commit something you are creating a
# new version of your code
#
#
# #git remote add origin https://gihub.com/username/project_name.git --> it will
# ...

# %%
file.close()

# %%
file
# Out:
# <_io.TextIOWrapper name='GIT_COMMANDS.txt' mode='r' encoding='cp1252'>

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-f3fc120c03c1> in <module>
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
f = open('target.txt','w')
print('this is the chapter of file handling in python we can done that by using print',file =f)
f.close()

# %%
ls
# Out:
#  Volume in drive E is Ajju
#  Volume Serial Number is 52D5-E649
#
#  Directory of E:\A\python_12pm
#
# 10/01/2019  12:16 PM    <DIR>          .
# 10/01/2019  12:16 PM    <DIR>          ..
# 10/01/2019  12:12 PM    <DIR>          .ipynb_checkpoints
# 09/02/2019  01:12 PM            86,432 BASICS _OF_PYTHON.ipynb
# 09/12/2019  12:55 PM            13,579 conditional statement in python.ipynb
# 10/01/2019  12:16 PM             8,213 file_handling.ipynb
# 09/26/2019  12:53 PM            27,748 Functions_in_python.ipynb
# 09/30/2019  11:34 AM             1,434 GIT_COMMANDS.txt
# 09/03/2019  01:11 PM         1,723,282 hello w.ipynb
# 09/23/2019  01:01 PM            20,069 Loops in Python.ipynb
# 09/09/2019  01:04 PM           449,823 operators in python.ipynb
# 09/30/2019  12:31 PM                31 README.md
# 10/01/2019  12:16 PM                80 target.txt
#               10 File(s)      2,330,691 bytes
#                3 Dir(s)  161,185,042,432 bytes free

# %%
f = open('target.txt','w+')

# %%
f.write('this is good for heath')
f.close()

# %%
f = open('target.txt','a')

# %%
f.writable()
# Out:
# True

# %%
f.tell()
# Out:
# 22

# %%
f.write('\napple is good for health')
f.close()

# %%
file= open('table.txt')

# %%
data=file.read()
file.close()

# %%
data = data.split('\n')

# %%
data
# Out:
# ['id\tname\tmath\tenglish',
#  '1\tajay\t45\t34',
#  '2\tmohit\t55\t66',
#  '3\tsahil\t56\t76',
#  '4\tyogi\t45\t54']

# %%
toda = list(map(lambda string : string.split(),data))
toda
# Out:
# [['id', 'name', 'math', 'english'],
#  ['1', 'ajay', '45', '34'],
#  ['2', 'mohit', '55', '66'],
#  ['3', 'sahil', '56', '76'],
#  ['4', 'yogi', '45', '54']]

# %%
print(*toda,sep='\n')
# Out:
# ['id', 'name', 'math', 'english']
# ['1', 'ajay', '45', '34']
# ['2', 'mohit', '55', '66']
# ['3', 'sahil', '56', '76']
# ['4', 'yogi', '45', '54']

# %%
for p,q,r,s in toda:
    print(p,q,r,s,sep='\t')
# Out:
# id	name	math	english
# 1	ajay	45	34
# 2	mohit	55	66
# 3	sahil	56	76
# 4	yogi	45	54

# %%
with open('t.txt','w') as f:
    f.write('12\t3\n23\t32\n12\t54\n65\t32\n32\t76\n')
    f.close()

# %%
f = open('t.txt')

# %%
data= f.read()

# %%
f.close()

# %%
data
# Out:
# '12\t3\n23\t32\n12\t54\n65\t32\n32\t76\n'

# %%
data = data.split('\n')
data
# Out:
# ['12\t3', '23\t32', '12\t54', '65\t32', '32\t76', '']

# %%
toda = list(map(lambda string : string.split(),data))
toda
# Out:
# [['12', '3'], ['23', '32'], ['12', '54'], ['65', '32'], ['32', '76'], []]

# %%
toda.pop()
# Out:
# []

# %%
toda
# Out:
# [['12', '3'], ['23', '32'], ['12', '54'], ['65', '32'], ['32', '76']]

# %%
t = []
for p,q in toda:
    t.append([int(p),int(q)])

# %%
t
# Out:
# [[12, 3], [23, 32], [12, 54], [65, 32], [32, 76]]

# %%
from functools import reduce

# %%
ms = reduce(lambda x,y : x + y,t)
ms
# Out:
# [12, 3, 23, 32, 12, 54, 65, 32, 32, 76]

# %%
ms = reduce(lambda x,y : x + y,ms)
ms
# Out:
# 341

# %%
file = open('something.jpg','rb')

# %%
data = file.read()
file.close()

# %%
data[:100]
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05'

# %%
len(data)
# Out:
# 61198

# %%
f = open('C:/Users/Ajay/Desktop/f.jpg','wb')

f.write(data)
f.close()

# %%
from PIL import Image

# %%
file = Image.open('something.jpg')

# %%
file
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x232D72E9400>

# %%
file = open('target.txt')
file.readline()
# Out:
# 'this is good for heath\n'

# %%
file.seek(0)
# Out:
# 0

# %%
file.readlines()
# Out:
# ['this is good for heath\n', 'apple is good for health']

# %%
file.close()

# %%
ls
# Out:
#  Volume in drive E is Ajju
#  Volume Serial Number is 52D5-E649
#
#  Directory of E:\A\python_12pm
#
# 10/02/2019  12:31 PM    <DIR>          .
# 10/02/2019  12:31 PM    <DIR>          ..
# 10/02/2019  12:13 PM    <DIR>          .ipynb_checkpoints
# 09/02/2019  01:12 PM            86,432 BASICS _OF_PYTHON.ipynb
# 09/12/2019  12:55 PM            13,579 conditional statement in python.ipynb
# 10/02/2019  12:31 PM             8,913 exception handling in python.ipynb
# 10/01/2019  12:34 PM           331,120 file_handling.ipynb
# 09/26/2019  12:53 PM            27,748 Functions_in_python.ipynb
# 09/30/2019  11:34 AM             1,434 GIT_COMMANDS.txt
# 09/03/2019  01:11 PM         1,723,282 hello w.ipynb
# 09/23/2019  01:01 PM            20,069 Loops in Python.ipynb
# 09/09/2019  01:04 PM           449,823 operators in python.ipynb
# 09/30/2019  12:31 PM                31 README.md
# 07/07/2019  11:24 AM            61,198 something.jpg
# 10/01/2019  12:25 PM                34 t.txt
# ...

# %%
file = open('file.txt','w')

# %%
file
# Out:
# <_io.TextIOWrapper name='file.txt' mode='w' encoding='cp1252'>

# %%
print(dir(file))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
file.readable()
# Out:
# False

# %%
file.writable()
# Out:
# True

# %%
file.write('something happend in this file')
# Out:
# 30

# %%
file.close()

# %%
f = open('file.txt')

# %%
f.read()
# Out:
# 'something happend in this file'

# %%
f.read()
# Out:
# ''

# %%
f.tell()
# Out:
# 30

# %%
f.seek(0)
# Out:
# 0

# %%
data = f.read()

# %%
data
# Out:
# 'something happend in this file'

# %%
f.close()

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-571e9fb02258> in <module>
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
file= open('file.txt','w')
file.write('apple is goood for health and real lyf tooo')
file.close()

# %%
file = open('file.txt','a')

# %%
file.writable()
# Out:
# True

# %%
file.readable()
# Out:
# False

# %%
file.write('\n i am not so gudd in dance')
file.close()

# %%
file = open('table.txt')
data = file.read()
file.close()

# %%
data
# Out:
# 'id\tname\tmath\tenglish\n1\tajay\t45\t34\n2\tmohit\t55\t66\n3\tsahil\t56\t76\n4\tyogi\t45\t54'

# %%
data = data.split('\n')

# %%
data
# Out:
# ['id\tname\tmath\tenglish',
#  '1\tajay\t45\t34',
#  '2\tmohit\t55\t66',
#  '3\tsahil\t56\t76',
#  '4\tyogi\t45\t54']

# %%
d = list(map(lambda string : string.split(),data))
d
# Out:
# [['id', 'name', 'math', 'english'],
#  ['1', 'ajay', '45', '34'],
#  ['2', 'mohit', '55', '66'],
#  ['3', 'sahil', '56', '76'],
#  ['4', 'yogi', '45', '54']]

# %%
for p,q,r,s in d:
    print(p,q,r,s,sep='\t')
# Out:
# id	name	math	english
# 1	ajay	45	34
# 2	mohit	55	66
# 3	sahil	56	76
# 4	yogi	45	54

# %%
file = open('target.txt')

# %%
file.readline()
# Out:
# 'this is good for heath\n'

# %%
file.readline()
# Out:
# 'apple is good for health'

# %%
file.seek(0)
# Out:
# 0

# %%
file.readlines()
# Out:
# ['this is good for heath\n', 'apple is good for health']

# %%
file.close()

# %%
file = open('t.txt')
data = file.read()
file.close()

# %%
data
# Out:
# '12\t3\n23\t32\n12\t54\n65\t32\n32\t76\n'

# %%
data = data.split('\n')

# %%
data
# Out:
# ['12\t3', '23\t32', '12\t54', '65\t32', '32\t76', '']

# %%
ml = list(map(lambda string : string.split(),data))
ml
# Out:
# [['12', '3'], ['23', '32'], ['12', '54'], ['65', '32'], ['32', '76'], []]

# %%
ml.pop()
# Out:
# []

# %%
ml
# Out:
# [['12', '3'], ['23', '32'], ['12', '54'], ['65', '32'], ['32', '76']]

# %%
t = []
for p,q in ml:
    t.append([int(p),int(q)])
    
print(t)
# Out:
# [[12, 3], [23, 32], [12, 54], [65, 32], [32, 76]]

# %%
from functools import reduce

# %%
ms = reduce(lambda x,y : x+y,t)
ms
# Out:
# [12, 3, 23, 32, 12, 54, 65, 32, 32, 76]

# %%
ms = reduce(lambda x,y : x+y,ms)
ms
# Out:
# 341

# %%
img = open('something.jpg','rb')
data = img.read()
img.close()

# %%
len(data)
# Out:
# 61198

# %%
with open('C:/Users/Ajay/Desktop/myimg.jpg','wb') as f:
    f.write(data)
    f.close()
