# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from decimal import Decimal
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train = pd.read_csv("E:/titanic/train.csv")
test = pd.read_csv('E:/titanic/test.csv')

# %%
print('shape of train dataset ',train.shape)
print('shape of test dataset ',test.shape)
# Out:
# shape of train dataset  (891, 12)
# shape of test dataset  (418, 11)

# %%
df = train.append(test)
df.head()
print('final df after joining both the dataframes ',df.shape)
# Out:
# final df after joining both the dataframes  (1309, 12)

# %%
df.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
# !python --version
# Out:
# Python 3.7.3

# %%
df.isnull().sum()
# Out:
# Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 12 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# Fare           1308 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 132.9+ KB

# %%
df.fillna(round(np.mean(df)),inplace=True)

# %%
df.isnull().sum()
# Out:
# Age               0
# Cabin          1014
# Embarked          2
# Fare              0
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived          0
# Ticket            0
# dtype: int64

# %%
df.Sex.value_counts().plot(kind='bar')

# %%
df.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
pd.crosstab(df.Sex,df.Survived).plot(kind='bar')
plt.show()

# %%
mean = df.Age.mean()

# %%
mean
# Out:
# 29.905019098548507

# %%
plt.figure(figsize=(18,6))
plt.scatter(x=df['Age'],y=df['Fare'])
plt.plot([0,80],[mean,mean],'g',lw=4)
plt.xticks([var for var in range(1,81)])
plt.title('graph of age vs fare')
plt.xlabel('AGe')
plt.ylabel('Fare')
plt.show()

# %%
df[df.Age == 35].max()
# Out:
# Age                           35
# Embarked                       S
# Fare                     512.329
# Name            Ward, Miss. Anna
# Parch                          1
# PassengerId                 1098
# Pclass                         3
# Sex                         male
# SibSp                          1
# Survived                       1
# Ticket         STON/O 2. 3101273
# dtype: object

# %%
df[df.Age >= 18]
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5    30.0          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 8    27.0          NaN        S   11.1333
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 15   55.0          NaN        S   16.0000
# 17   30.0          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19   30.0          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# 21   34.0          D56        S   13.0000
# 23   28.0           A6        S   35.5000
# 25   38.0          NaN        S   31.3875
# 26   30.0          NaN        C    7.2250
# 27   19.0  C23 C25 C27        S  263.0000
# ...

# %%
df['agestatus'] = np.where(df.Age >= 18,'adult','child')

# %%
df.agestatus.value_counts()
# Out:
# adult    1155
# child     154
# Name: agestatus, dtype: int64

# %%
val = df.agestatus.value_counts()

# %%
plt.figure(figsize=(10,5))
plt.bar(x=val.index,height=val,color=['r','g'])
plt.show()

# %%
pd.crosstab(df.Pclass,df.Sex).plot(kind='bar',title='Pclass and Sex')
plt.show()

# %%
df.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket agestatus
# 0       3    male      1       0.0         A/5 21171     adult
# 1       1  female      1       1.0          PC 17599     adult
# 2       3  female      0       1.0  STON/O2. 3101282     adult
# 3       1  female      1       1.0            113803     adult
# ...

# %%
nba = pd.read_csv('E:/datasets/nba.csv')

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.dropna(inplace=True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0
# 6            LSU  1170960.0
# 7        Gonzaga  2165160.0

# %%
nba.max(numeric_only=True)
# Out:
# Number          99.0
# Age             40.0
# Weight         279.0
# Salary    22875000.0
# dtype: float64
