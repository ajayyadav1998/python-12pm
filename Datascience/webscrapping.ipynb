# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://cdn.pixabay.com/photo/2014/04/14/20/11/japanese-cherry-trees-324175_960_720.jpg'

# %%
req = requests.get(url)

# %%
open('image.jpg','wb').write(req.content)
# Out:
# 67840

# %%
from PIL import Image

# %%
img = Image.open("image.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x640 at 0x2748B472A90>
